# %%
import os 
import cv2 
import numpy as np 
from ultralytics import YOLO, settings 
from IPython.display import display, Image 
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/samsusikar/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# /Users/samsusikar/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
root_dir = '/Users/samsusikar/Downloads/car image segmentation/archive/No_Apply_Grayscale/No_Apply_Grayscale/Vehicles_Detection.v8i.yolov8'
train_img_sample = root_dir + '/train/images/frame_0087_jpg.rf.6911e25ecb00139750616b606571e714.jpg'
test_img_sample = root_dir + '/test/images/frame_1004_jpg.rf.a6f441255e54620ea11fb3cf34fc0a97.jpg'

# %%
train_img = cv2.imread(os.path.join(train_img_sample))
test_img = cv2.imread(os.path.join(test_img_sample))

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(train_img)
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(test_img)
plt.axis('off')

plt.show()

# %%
model = YOLO("yolov8n.yaml")
results = model.train(data = os.path.join(root_dir, 'data.yaml'), epochs = 200)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.9.6 torch-2.5.1 CPU (Apple M3 Pro)
# ...

# %%
print(results)
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3, 4])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x3493a3850>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
# ...

# %%
def detection_result(images):
    output = model(images)
    
    # visualise
    for i, r in enumerate(output):
        # numpy array in RGB order
        im_bgr = r.plot()
        
        # opencv iBMI display BGR
        im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)
        
        plt.axis('off')
        plt.imshow(im_rgb)
        plt.show()

# %%
test_image_paths = [os.path.join(root_dir, 'test/images/', img) for img in os.listdir(os.path.join(root_dir, 'test/images/')) if img.endswith('.jpg')]

detection_result(test_image_paths)
# Out:
# 0: 640x640 1 Bus, 15 Cars, 9 Motorcycles, 3 Pickups, 54.4ms
# 1: 640x640 24 Cars, 54.4ms
# 2: 640x640 38 Cars, 1 Pickup, 54.4ms
# 3: 640x640 10 Cars, 1 Motorcycle, 54.4ms
# 4: 640x640 4 Cars, 54.4ms
# 5: 640x640 1 Car, 54.4ms
# 6: 640x640 (no detections), 54.4ms
# 7: 640x640 30 Cars, 1 Motorcycle, 1 Pickup, 54.4ms
# 8: 640x640 20 Cars, 6 Motorcycles, 4 Pickups, 54.4ms
# 9: 640x640 1 Car, 54.4ms
# 10: 640x640 2 Cars, 1 Pickup, 54.4ms
# 11: 640x640 25 Cars, 2 Motorcycles, 2 Pickups, 54.4ms
# 12: 640x640 19 Cars, 1 Motorcycle, 54.4ms
# Speed: 1.7ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
